# %% [markdown]
# <a href="https://colab.research.google.com/github/TienNguyen0712/data-science-foundations/blob/main/math_statistic/hypothesis_testing/hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📚 **Các thuật ngữ được sử dụng**

# %% [markdown]
# ## **1. Tổng thể - Mẫu**
# - **Tổng thể (population):** toàn bộ đối tượng quan tâm (tất cả người dùng của app)
# - **Mẫu (sample):** một phần lấy ra để đo (người dùng tham gia testing)
#
# ## **2. Tham số - Thống kê**
# - **Tham số:** đại lượng "thật" của tổng thể (tỷ lệ mua hàng thật sự)
# - **Thóng kê:** đại lượng tính từ mẫu (tỷ lê mua hàng quan sát được trong test)
#
# ## **3. Giả thuyết H0 và H1**
# - **H0 (giả thuyết không):** không khác biệt / không hiệu ứng
# - **H1 (giả thuyết đối):** có khác biệt / có hiệu ứng
#
# ## **4. Mức ý nghĩa alpha**
# - **a = 0.05:** nếu ta kết luạn ta chấp nhận tối đa 5% nguy cơ kết quả sai kiểu đó
#
# ## **5. p-value**
# - **p-value:** là mức "bất ngờ" của dữ liệu nếu H0 đúng
# - **p_value <= a -> dữ liệu quá "bât ngờ" nếu H0 đúng - > bác bỏ H0**
#
# ## **6. Sai lầm loại I và II**
# - **Loại I (false positive):** bác bỏ H0 dù H0 đúng
# - **Loại II (true positive):** không bác bỏ H0 dù H1 đúng
#
# ## **Kiểm định tham số và phi tham số**
#
# - **Kiểm định tham só:** là kiểm định dựa trên giả định về phân phối của dữ liệu, thường là phân phối chuẩn, và kiểm định trực tiếp các tham só của phân phối
#
# - **Kiểm định phi tham số:** là kiểm định không yêu cầu giả định, thường dựa trên thứ hạng hoặc dấu của dữ liệu thay vì giá trị gốc

# %% [markdown]
# # 🎯 **Các kiểm định thường dùng**

# %% [markdown]
# ## **1. Kiểm định z-test**

# %% [markdown]
# ## **2. Kiểm định t-test (1 mẫu, 2 mẫu, cặp)**

# %% [markdown]
# ## **3. Chi-square**

# %% [markdown]
# ## **4. ANOVA**

# %% [markdown]
# ## **5. Mann-Whitney**

# %% [markdown]
# ## **6. Wilcoxon**

# %% [markdown]
# ## **7. Kruskal-Walls**

# %% [markdown]
# ## **8. F-test**

# %% [markdown]
# # 🔍 **Quy trình kiểm định giả thuyết**

# %% [markdown]
# 1. Đặt H0 và H1
# 2. Chọn mức ý nghĩa alpha
# 3. Thu thập dữ liệu
# 4. Tính thống kê kiểm định
# 5. Tính p-value
# 6. Kết luận
