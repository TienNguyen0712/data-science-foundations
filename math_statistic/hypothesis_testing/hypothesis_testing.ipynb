# %% [markdown]
# <a href="https://colab.research.google.com/github/TienNguyen0712/data-science-foundations/blob/main/math_statistic/hypothesis_testing/hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📚 **Các thuật ngữ được sử dụng**

# %% [markdown]
# ## **1. Tổng thể - Mẫu**
# - **Tổng thể (population):** toàn bộ đối tượng quan tâm (tất cả người dùng của app)
# - **Mẫu (sample):** một phần lấy ra để đo (người dùng tham gia testing)
#
# ## **2. Tham số - Thống kê**
# - **Tham số:** đại lượng "thật" của tổng thể (tỷ lệ mua hàng thật sự)
# - **Thóng kê:** đại lượng tính từ mẫu (tỷ lê mua hàng quan sát được trong test)
#
# ## **3. Giả thuyết H0 và H1**
# - **H0 (giả thuyết không):** không khác biệt / không hiệu ứng
# - **H1 (giả thuyết đối):** có khác biệt / có hiệu ứng
#
# ## **4. Mức ý nghĩa alpha**
# - **a = 0.05:** nếu ta kết luạn ta chấp nhận tối đa 5% nguy cơ kết quả sai kiểu đó
#
# ## **5. p-value**
# - **p-value:** là mức "bất ngờ" của dữ liệu nếu H0 đúng
# - **p_value <= a -> dữ liệu quá "bât ngờ" nếu H0 đúng - > bác bỏ H0**
#
# ## **6. Sai lầm loại I và II**
# - **Loại I (false positive):** bác bỏ H0 dù H0 đúng
# - **Loại II (true positive):** không bác bỏ H0 dù H1 đúng
#
# ## **7. Kiểm định tham số và phi tham số**
#
# - **Kiểm định tham só:** là kiểm định dựa trên giả định về phân phối của dữ liệu, thường là phân phối chuẩn, và kiểm định trực tiếp các tham só của phân phối
#
# - **Kiểm định phi tham số:** là kiểm định không yêu cầu giả định, thường dựa trên thứ hạng hoặc dấu của dữ liệu thay vì giá trị gốc

# %% [markdown]
# # 🎯 **Các kiểm định thường dùng**

# %% [markdown]
# ## **1. Kiểm định z-test**
#
# > Trung bình mẫu cách trung bình giả định bao nhiêu độ lệch chuẩn

# %% [markdown]
# **Dùng khi:**
#
# - So sánh **trung bình**
# - Biết độ lệch chuẩn tổng thể
# - Mẫu lớn hơn hoặc băng 30 hoặc tổng thể chuẩn
#
# **Giả thuyết**
#
# - *H0*: $$\mu = \mu_0$$
# - *H1*: $$\mu \ne \mu_0  \quad / \quad \mu > \mu_0 \quad / \quad \mu < \mu_0 $$
#
# **Ví dụ**
#
# Bộ Y tế cho biết chiều cao trung bình nam giới là 170 cm, độ lệch chuẩn σ = 6 cm (biết trước). Đo chiều cao 100 sinh viên. Chiều cao trung bình của nhóm sinh viên này có khác 170cm hay không
#
# **Ứng dụng trong thực tế**
# - Sản xuất công nghiệp
# - Khảo sát dân số quy mô lớn

# %% [markdown]
# ## **2. Kiểm định t-test (1 mẫu, 2 mẫu, cặp)**
#
# > Trung bình mẫu cách trung bình giả định bao nhiêu độ lệch chuẩn

# %% [markdown]
# ### **2.1. One-sample t-test (1 mẫu)**
#
# **Dùng khi**
#
# - So sánh **1 trung bình**
# - Không biết lệch chuẩn
# - Mẫu nhỏ
#
# **Ví dụ**
#
# Một nhà máy tuyên bố trọng lượng trung bình của gói bánh là 100g. Bạn lấy 30 gói bánh và cân. Hỏi trọng lượng thực tế có khác 100g không?
#
# **Ứng dụng trong thực tế**
# - Kiểm soát chất lượng sản phẩm
# - Đánh giá tiêu chuẩn sản phẩm

# %% [markdown]
# ### **2.2. Independent t-test (2 mẫu độc lập)**
#
# > Hai số này có liên quan tới nhau không
#
# **Dùng khi**
#
# - So sánh **2 trung bình**
# - Dữ liệu chuẩn
# - Phương sai bằng nhau
#
# **Ví dụ**
#
# Một trường đại học muốn so sánh **điểm trung bình** môn Toán của
# - Sinh viên học online
# - Sinh viên học trực tiếp
#
# Hỏi hai phương pháp học này có tạo ra sự khác biệt hay không?
#
# **Ứng dụng trong thực tế**
# - Giáo dục
# - So sánh hiệu quả hai phương pháp quản trị / y tế

# %% [markdown]
# ### **2.3. Paired t-test (1 mẫu)**
#
# > Hai số này có liên quan tới nhau không
#
# **Dùng khi**
#
# - So sánh trước và sau
# - Cùng đối tượng
#
# **Ví dụ**
#
# Một phòng gym muốn đo cân nặng của học viên trước và sau 3 tháng tập luyện. Hỏi xem chương trình tập luyện có giúp giảm cân hay không?
#
# **Ứng dụng trong thực tế**
# - Y tế - sức khỏe
# - Đánh giá hiệu quả can thiệp

# %% [markdown]
# ## **3. Chi-square**

# %% [markdown]
# ### **3.1. Chi-square độc lập**
#
# **Dùng khi**
# - Hai biến phân loại có liên quan nhau không
# - Dữ liệu liên tục
# - Mẫu nhỏ
#
# **Giả thuyết**
# - *H0:* Hai biến **độc lập**
# - *H1:* Hai biến **có liên quan**
#
# **Ví dụ**
#
# Một công ty muốn biết **giới tính** có liên quan đến việc mua **sản phảm A hay B** không. Hỏi giới tính và lựa chọn sản phảm có độc lập với nhau hay không?
#
# **Ứng dụng trong thực tế**
# - Marketing
# - Phân tích hàng vi khách hàng

# %% [markdown]
# ### **3.2. Chi-square goodness of fit**
#
# **Dùng khi**
# - Xác định xem dữ liệu có phù hợp cho **phân phối giả định hay không?**
# - Dữ liệu liên tục
# - Mẫu nhỏ
#
# **Giả thuyết**
# - *H0:* Phân phói đúng như kỳ vọng
# - *H1:* Phân phối khác
#
# **Ví dụ**
#
# Một nhà sản xuất kẹo tuyên bố tỷ lệ màu kẹo là:
# - Đỏ: 30%
# - Xanh: 40%
# - Vàng: 30%
#
# Bạn lấy ngẫu nhiên 200 viên kẹo và đếm số lượng từng màu. Phân bố màu kẹo **quan sát dược** có phù hợp với phân bố mà nhà sản xuất công bố hay không?
#
# **Ứng dụng trong thực tế**
# - kiểm tra tính ngẫu nhiên
# - So sánh phân bố lý thuyết và thực tế
# - Kiểm định xúc xắc, màu sản phẩm

# %% [markdown]
# ## **4. ANOVA**
#
# > Sự khác biệt giữa các nhóm có lớn hơn nhiễu nội bộ không

# %% [markdown]
# **Dùng khi**
# - So sánh **>= 3 trung bình**
# - Dữ liệu chuẩn
# - Phương sai bằng nhau
#
# **Giả thuyết**
#
# - *H0*: $$\mu_1 = \mu_2 = \mu_3$$
# - *H1*: Ít nhất 1 u khác
#
# **Ví dụ**
#
# So sánh **điểm trung bình** của sinh viên học theo **phương pháp giảng dạy khác nhau**. Hỏi có ít nhất một phương pháp cho kết quả khác biệt hay không?
#
# **Ứng dụng trong thực tế**
# - Giáo dục
# - Thí nghiệm khoa học

# %% [markdown]
# ## **5. Mann-Whitney U test**

# %% [markdown]
# **Dùng khi**
#
# - Kiểm định phi tham số
# - Thay cho **independent t-test**
# - Dữ liệu không chuẩn
# - Thang đo thứ bậc
#
# **Giả thuyết**
#
# - H0: Hai phân phối giống nhau
#
# **Ví dụ**
#
# So sánh **mức độ hài lòng của khác hàng (thang điểm 1-5)** giữa hai cửa hàng, dữ liệu **không phân phối chuẩn**
#
# **Ứng dụng trong thực tế**
# - Khảo sát xã hội
# - Nghiên cứu hành vi

# %% [markdown]
# ## **6. Wilcoxon Signed-Rank test**

# %% [markdown]
# **Khi dùng**
#
# - Thay cho paired t-test
# - Trước - sau
# - Không chuẩn
#
# **Ví dụ**
#
# Một bệnh viện đo **mức độ đau (thang 1–10)** của bệnh nhân trước và sau khi dùng thuốc mới. **Dữ liệu không phân phối chuẩn.** Thuốc mới có làm giảm mức độ đau không?
#
# **Ứng dụng trong thực tế**
# - Y học, Tâm lý học
# - Khảo sát thang đo thứ bậc

# %% [markdown]
# ## **7. Kruskal-Walls**

# %% [markdown]
# **Khi dùng**
# - Thay cho ANOVA
# - Lớn hơn hoặc bằng 3 nhóm
# - Dữ liệu không chuẩn
#
# **Giả thuyết:**
#
# - *H0*: Các nhóm có cùng phân phối giống nhau
# - *H1*: Có ít nhất một nhóm khác nhau
#
# **Ví dụ**
#
# Một giảng viên muốn so sánh **mức độ hài lòng sinh viên (1–5)** đối với **3 phương pháp** giảng dạy:
# - Nhóm A: Dạy truyền thống
# - Nhóm B: Dạy kết hợp (blended)
# - Nhóm C: Dạy online
#
# **Dữ liệu khảo sát không phân phối chuẩn.** Mức độ hài lòng của sinh viên giữa 3 phương pháp có **khác nhau hay không?**
#
# **Ứng dụng trong thực tế**
# - Y học, Tâm lý học
# - So sánh thời gian hoàn thành 3 quy trình

# %% [markdown]
# ## **8. F-test (Kiểm định phương sai)**
#
# > Biến thiên lớn nhất với biến thiên nhỏ nhất
#
# **Khi dùng**
# - So sánh **2 phương sai**
# - Kiểm tra giả định ANOVA
#
# **Giả thuyết**
#
# - *H0*: $$σ^2_1 = σ^2_2$$
# - *H1*: $$σ^2_1 \ne σ^2_2 \quad / \quad σ^2_1 > σ^2_2 \quad / \quad σ^2_1 < σ^2_2 \quad / \quad$$
#
# **Ví dụ**
#
# Một công ty có 2 máy đóng chai. Quản lý muốn biết độ ổn định của hai máy có giống nhau không. Bạn đo thể tích chai từ mỗi máy. Phương sai thể tích của hai máy này có bằng nhau hay không?
#
# **Ứng dụng trong thực tế**
# - Kiểm soát chất lượng
# - Kiêm tra giả định trước khi dùng t-test hoặc ANOVA

# %% [markdown]
# # 🔍 **Quy trình kiểm định giả thuyết**

# %% [markdown]
# 1. Đặt H0 và H1
# 2. Chọn mức ý nghĩa alpha
# 3. Thu thập dữ liệu
# 4. Tính thống kê kiểm định
# 5. Tính p-value
# 6. Kết luận
