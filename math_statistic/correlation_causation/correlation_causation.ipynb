# %% [markdown]
# <a href="https://colab.research.google.com/github/TienNguyen0712/data-science-foundations/blob/main/math_statistic/correlation_causation/correlation_causation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ➕➖**Các khái niệm cơ bản**

# %% [markdown]
# # 📘**Correlation (Tương quan)**

# %% [markdown]
# ## **Pearson Correlation (Tuyến tính)**

# %% [markdown]
# **Định nghĩa**
#
# Pearson đo mức độ tuyến tish giữa hai biến liên tục. Là Cov đã chuẩn hóa
#
# $$r = Cov(X.Y) / σ_xσ_y$$
#
# **Dùng khi**
# - Quan hệ tuyến tính
# - Không có ngoại lai nghiêm trọng
# - Dữ liệu gần phân phối chuẩn

# %% [markdown]
# ## **Spearman Correlation (Phi tuyến)**

# %% [markdown]
# **Định nghĩa**
#
# Spearman đo mối quan hệ dơn điệu.
# > Khi X tăng Y có xu hướng tăng hoặc giảm, không cần tuyến tính. Dựa trên thứ hạng và không dùng giá trị gốc
#
# **Công thức**
# - Chuyển X,Y -> rank
# - Tính Pearson trên rank
#
# $$p = cor(rank(X), rank(Y))$$
#
# **Dùng khi**
# - Quan hệ phi tuyến nhưng đơn điệu
# - Dữ liệu lệch
# - Dữ liệu thứ bậc

# %% [markdown]
# ## **Kendall's Tau**

# %% [markdown]
# **Định nghĩa**
#
# Kendall đo xác suất hai biến cùng "đồng thuận" về thứ tự.
#
# **Công thức**
#
# $$r = P(Dồng thuận) -  P(nghịch)$$
#
# **Dùng khi**
# - Mẫu nhỏ
# - Nhiều giá trị trùng
# - Cần diễn giải xác suất rõ ràng

# %% [markdown]
# ## **Partial Correlation**

# %% [markdown]
# **Định nghĩa**
#
# Đo mối liên hệ giữa X và Y sau khi đã loại bỏ một vài ảnh hưởng cảu một (hoặc nhiều) biến kiểm soát Z
#
# > Nếu giữ Z khổng đổi, X và Y còn liên quan với nhau không?
#
# **Công thức**
#
# $$r_{xy.z} = r_{XY} -  r_{XZ}r_{YZ} / \sqrt{(1 - r^2_{XZ})(1 - r^2_{YZ})}$$
#
# **Dùng khi**
# - xem mối quan hệ giữa X và Y khi loại Z

# %% [markdown]
# ## **Tính chất & diễn giải**

# %% [markdown]
# Cor ∈ [-1, 1]
#
# Cor = 0 có nghĩa gì?
#
# Cor cao có chắc là tốt?
#
# Sensitivity với outliers

# %% [markdown]
# ## **Trực quan hóa cho Correlation**

# %% [markdown]
# Scatter plot
#
# Pair plot
#
# Heatmap
#
# Nhận diện quan hệ phi tuyến

# %% [markdown]
# ## **Những bẫy thường gặp**

# %% [markdown]
# Correlation ≠ Causation
#
# Spurious correlation
#
# Simpson’s Paradox
#
# Confounding variables

# %% [markdown]
# Feature selection
#
# Multicollinearity
#
# Correlation matrix trong EDA
#
# Giới hạn của correlation trong ML

# %% [markdown]
# # 📕**Causation (Nhân quả)**

# %% [markdown]
# ## **Tư duy nhân quả (Causal Thinking)**

# %% [markdown]
# Can thiệp vs quan sát
#
# Counterfactuals
#
# “What if” questions
#
# Causal vs predictive modeling

# %% [markdown]
# 🔹 Những câu hỏi cốt lõi
#
# “Nếu can thiệp vào X, Y có thay đổi không?”
#
# “Điều gì xảy ra nếu X không xảy ra?”
#
# 🔹 Các khái niệm nền
#
# Counterfactuals (điều gì sẽ xảy ra nếu…)
#
# Confounder
#
# Mediator
#
# Collider

# %% [markdown]
# ## **Causal Graphs & DAGs**

# %% [markdown]
# Directed Acyclic Graphs (DAG)
#
# Confounder, Mediator, Collider
#
# Backdoor & frontdoor criterion
#
# Do-operator (ở mức khái niệm)

# %% [markdown]
# Experimental Causation (Nhân quả qua thí nghiệm)

# %% [markdown]
# ## **Randomized Controlled Trial (RCT)**

# %% [markdown]
# Randomized Controlled Trials (RCT)
#
# A/B Testing
#
# Randomization & bias
#
# Internal / External validity

# %% [markdown]
# ## **Observational Causation**

# %% [markdown]
# Linear regression (causal view)
#
# Matching & Propensity Score
#
# Difference-in-Differences
#
# Instrumental Variables
#
# Regression Discontinuity

# %% [markdown]
# ## **Assumptions & Pitfalls**

# %% [markdown]
# Selection bias
#
# Omitted variable bias
#
# Measurement error
#
# Over-control & collider bias

# %% [markdown]
# Marketing attribution
#
# Pricing strategy
#
# Policy evaluation
#
# ML + Causal Inference
