# %% [markdown]
# <a href="https://colab.research.google.com/github/TienNguyen0712/data-science-foundations/blob/main/math_statistic/correlation_causation/correlation_causation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ➕➖**Các khái niệm cơ bản**

# %% [markdown]
# # 📘**Correlation (Tương quan)**

# %% [markdown]
# ## **1. Pearson Correlation (Tuyến tính)**

# %% [markdown]
# **Định nghĩa**
#
# Pearson đo mức độ tuyến tish giữa hai biến liên tục. Là Cov đã chuẩn hóa
#
# $$Cor(X, Y) = Cov(X.Y) / σ_xσ_y$$
#
# **Dùng khi**
# - Quan hệ tuyến tính
# - Không có ngoại lai nghiêm trọng
# - Dữ liệu gần phân phối chuẩn

# %% [markdown]
# ## **2. Spearman Correlation (Phi tuyến)**

# %% [markdown]
# **Định nghĩa**
#
# Spearman đo mối quan hệ dơn điệu.
# > Khi X tăng Y có xu hướng tăng hoặc giảm, không cần tuyến tính. Dựa trên thứ hạng và không dùng giá trị gốc
#
# **Công thức**
# - Chuyển X,Y -> rank
# - Tính Pearson trên rank
#
# $$p = cor(rank(X), rank(Y))$$
#
# **Dùng khi**
# - Quan hệ phi tuyến nhưng đơn điệu
# - Dữ liệu lệch
# - Dữ liệu thứ bậc

# %% [markdown]
# ## **3. Kendall's Tau**

# %% [markdown]
# **Định nghĩa**
#
# Kendall đo xác suất hai biến cùng "đồng thuận" về thứ tự.
#
# **Công thức**
#
# $$r = P(Dồng thuận) -  P(nghịch)$$
#
# **Dùng khi**
# - Mẫu nhỏ
# - Nhiều giá trị trùng
# - Cần diễn giải xác suất rõ ràng

# %% [markdown]
# ## **4. Partial Correlation**

# %% [markdown]
# **Định nghĩa**
#
# Đo mối liên hệ giữa X và Y sau khi đã loại bỏ một vài ảnh hưởng cảu một (hoặc nhiều) biến kiểm soát Z
#
# > Nếu giữ Z khổng đổi, X và Y còn liên quan với nhau không?
#
# **Công thức**
#
# $$r_{xy.z} = r_{XY} -  r_{XZ}r_{YZ} / \sqrt{(1 - r^2_{XZ})(1 - r^2_{YZ})}$$
#
# **Dùng khi**
# - xem mối quan hệ giữa X và Y khi loại Z

# %% [markdown]
# ## **5. Tính chất & diễn giải**

# %% [markdown]
# Hệ số tương quan đo:
#
# > Mức độ và chiều hướng liên hệ tuyến tính giữa hai biến ngẫu nhiên X và Y
#
# Cor luôn nằm trong -1 đến 1
# - Cov là hiệp phương sai chưa được chuẩn hóa
# - Chia cho tích độ lệch chuẩn -> chuẩn hóa về cùng thang đó
#
# **Cor = 0 có nghĩa là không tồn tại mối quan hệ tuyến tính giữa hai biến**
#
# Tuy nhiên không có nghĩa là
# - Hai biến không liên quan
# - Hai biến độc lập (trừ trường hợp đặc biệt)
#
# **Cor cao** chưa chắc là tốt
# - Cor cao nhưng nhiều khi đó là quan hệ nhân quả
# - Cor có có thể do ngoại lai
# - Yrong mô hình dự đoán Cor cao đôi khi còn xấu
#
# Do được tính theo trung bình và phương sai
# - Ảnh hưởng rất mạnh bởi ngoại lai

# %% [markdown]
# ## **6. Trực quan hóa cho Correlation**

# %% [markdown]
# **Scatter plot:**
# - Cor = +! (Tương quan dương mạnh)
#   - Điểm nằm gần dường thằng dóc lên
#   - X tăng -> Y tăng tuyến tính
# ```
# •
#   •
#     •
#       •
#         •
#
# ```
# - Cor = -1 (tương quan âm mạnh)
#   - Điểm nằm gần đường thằng dốc xuống
#   - X tăng -> Y giảm
# ```
#         •
#       •
#     •
#   •
# •
#
# ```
# - Cor = 0
#   - Quan hệ rất rõ
#   - Nhưng Cor = 0
# - Không có quan hệ
# ```
# •   •     •
#     •  •
#   •      •
#       •
#
# ```
# - Có quan hệ
#
# **Xác định quan hệ phi tuyến**
#
# ```
#     •       •
#       •   •
#         •
#       •   •
#     •       •
#
# Hình chữ U
#
# ```
#
# ```
# •
#   •
#     •
#       •
#          •
#
# Dạng cong tăng
#
# ```
#
# ```
# •
# •
# •
#       •
#       •
#       •
#
# Dạng bậc thang
# ```
#
# ```
#    •     •
#  •   • •   •
#        •
#
#
# Dạng chu kỳ
# ```
#
# **Heatmap:**
# - Dùng khi có nhiều biến
# - Dùng khi muốn xem tương quan cặp đôi
# - Màu đậm -> Cor lớn
# - Đường chéo = 1
#
# **Để xác định quan hệ:** Cần vẽ thêm đường Loess / lowess, so sánh Pearson, Spearman, biến đổi dữ liệu
#
# > Báo cáo Cor sau khi xem Scatter plot

# %% [markdown]
# ## **7. Những bẫy thường gặp**

# %% [markdown]
# **Tương quan khác với ý nghĩa nhân quả**
#
# Hai biến cùng thay đổi không có nghĩa là biến này gây ra biến kia. Corr chỉ trả lời cho có tăng hay không, không trả lời cho ai gây ra, có yếu tố thứ 3 hay không
#
# **Tương quan giả**
#
# Hai biến có Corr cao nhưng hoàn toàn không liên quan về logic:
# - ngẫu nhiên
# - Cũng bị ảnh hưởng bởi thời gian
# - Trùng xu hướng
#
# **Xu hướng quan sát ở từng nhóm con bị đảo ngược khi gộp dữ liệu lại**
#
# - **Ví dụ**
#   - Xét tỉ lệ dậu
#     - Trường A đậu cao hơn B ở mọi khoa
#     - Nhưng tổng thể B đậu cao hơn A
# - **Nguyên nhân**
#   - Kích thước nhóm không đều
#   - Biến ẩn
#
# **Biến nhiễu**
#
#  Một biến Z ảnh hưởng đến biến X và ảnh hưởng đến biến Y. Tuy nhiên không được đưa vào phân tích
#
# - **Nhận diện**
#   - Biến liên quan đến cả X và Y
#   - Làm sai lệch két quả nhân quả

# %% [markdown]
# # 📕**Causation (Nhân quả)**
#
# > Cái gì xảy ra chứu không chỉ là hai tthuws này có liên quan với nhau không?

# %% [markdown]
# ## **1. Tư duy nhân quả (Causal Thinking)**

# %% [markdown]
# 🔍 **Quan sát**
#
# > Khi X xảy ra thì Y thường nhưu thế nào
#
# Ta chỉ nhìn dữ liệu như nó xảy ra tự nhiên
#
# **Ví dụ**
# - Thấy khách xem nhiều -> chốt đơn cao
#
# **Tuy nhiên**
#
# Ta không thể kiểm soát được nguyên nhânm, dễ dính các biến ẩn
#
# 🔧 **Can thiệp**
# > Nhân quả chi có khi ta can thiệp
#
# Ta chủ động thay đổi 1 biến, giữ các thứ khác càng giống càng tốt
#
# ❓**Suy nghĩ một việc đã không xảy ra nhưng có thể đã xảy ra**
#
# - Nếu hôm đó không giảm giá, tôi có bán được đơn hay không
# - Nếu khách này không thấy quảng cáo, ho có mua không
#
# > 📌 Counterfactuals (điều gì sẽ xảy ra nếu) khác với Dự đoán
#
# 🛠 **Đặt câu hỏi cho tư duy nhân quả**
#
# Nếu như ta đặt câu hỏi sẽ ứng với mỗi tư duy khác nhau:
#
# - "Khách này có mua không" -> Predictive
# - "Nếu tôi giảm 5% khách có mua không" -> Nhân quả
# - "Nếu không sale, chuyện gì sẽ xảy ra" -> Điều gì xảy ra nếu
# - "Nếu đổi phòng showroom, doanh thu có tăng" -> Intervention
#
# 📠 **Mô hình dự đoán và Nhân quả**
#
# - Dự đoán
# > Chuyện gì sẽ xảy ra
#
# **Đặc điểm**
# - Quan tâm độ chính xác
# - Không cần biết vì sao
#
# **Dùng khi**
# - Gợi ý sản phẩm
# - Phân loại spam
#
# - Nhân quả
# > Biết nên làm gì để thay đổi kết quả
#
# **Đặc điểm**
# - Quan tâm can thiệp
# - Trả lời câu hỏi ra quyết định
#
# **Dùng khi**
# - Chính sách
# - Chiến lược
# - Marketing

# %% [markdown]
# ## **2. Causal Graphs & DAGs**

# %% [markdown]
# ### **2.1. Directed Acyclic Graphs (DAG)**
#
# Là đồ thị có hướng và không có chu trình
# - **Nút**: Biến
# - **Mũi tên**: Quan hệ nhân quả giả định (A gây ảnh hưởng lên B)
# - Không có chu trình
#
# **Ví dụ**
#
# Muốn biết quảng cáo (X) có làm tăng doanh thu (Y) không.
#
# Một DAG đơn giản:
# - X -> Y (quảng cáo có ảnh hưởng doanh thu)
#
# Nhưng thực tế có thể có biến khác
# - Mùa vụ (S) ảnh hưởng cả quảng cáo và doanh thu S -> X và S -> Y
#
# Khi đó DAG:
#
# S -> X -> Y hoặc S -> Y
#
# **Vai trò**
# - Giúp nhìn ra đường gây nhiễu
# - Quyết định nên điều chỉnh biến nào khi ướng lượng nhân quả

# %% [markdown]
# ### **2.2. Confounder, Mediator, Collider**
#
# **Confounder (Biến gây nhiều):** Là biên gây ảnh hưởng đến cả X và Y. Nếu không điều chỉnh biến này, ta sẽ nhầm lẫn tương quan thành nhân quả
#
# **Ví dụ**
#
# - X: uống cà phê
# - Y: ung thư phổi
# - Z: uống thước
#
# DAG:
#
# - Z → X (người hút thuốc hay uống cà phê hơn)
# - Z → Y (hút thuốc làm tăng ung thư phổi)
# - X → Y (bạn đang muốn biết có thật không)
#
# Nếu không kiểm soát Z ta sẽ thấy X và Y tương quan mạnh, nhưng thực ra phần lớn do Z
#
# **Mediator (Biến trung gian):** Nằm trên đường nhân quả X sang Y. Giúp giải thích cơ chế tác động
#
# **Ví dụ**
# - X: học thêm
# - M: Số giờ luyện thi
# - Y: Diểm thi
#
# DAG: X -> M -> Y
#
# Nếu mục tiêu là tổng tác động (total effect) của X lên Y → không nên adjust mediator (vì bạn sẽ “cắt” một phần tác động thật).
#
# Nếu mục tiêu là tác động trực tiếp (direct effect) không qua M → có thể cần điều chỉnh M (nhưng cần cẩn thận giả định).
#
#
# **Collider C** là biến nhận hai mũi tên đi vào:
#
# X → C ← Y hoặc A → C ← B
#
# Tính chất “nguy hiểm”:
#
# - Không điều kiện (không điều chỉnh C): đường X — Y qua collider thường bị chặn (blocked)
# - **Nếu bạn điều chỉnh/điều kiện theo collider**: Mở đường liên hệ giả (spurious association) → **gây selection bias / collider bias.**
#
# **Ví dụ**
# - X: kỹ năng
# - Y: “quen biết”/network
# - C: được nhận vào công ty
#
# DAG:
#
# X → C ← Y
#
# Nếu chỉ nhìn dữ liệu của người đã được nhận (condition on C), có thể thấy:
#
# - kỹ năng cao thường đi kèm network thấp (vì “đã đậu” rồi thì một cái mạnh bù cái yếu), dù ngoài đời X và Y có thể độc lập.

# %% [markdown]
# ### **2.3. Backdoor & frontdoor criterion**

# %% [markdown]
# ### **2.4. Do-operator**

# %% [markdown]
# Experimental Causation (Nhân quả qua thí nghiệm)

# %% [markdown]
# ## **Randomized Controlled Trial (RCT)**

# %% [markdown]
# Randomized Controlled Trials (RCT)
#
# A/B Testing
#
# Randomization & bias
#
# Internal / External validity

# %% [markdown]
# ## **Observational Causation**

# %% [markdown]
# Linear regression (causal view)
#
# Matching & Propensity Score
#
# Difference-in-Differences
#
# Instrumental Variables
#
# Regression Discontinuity

# %% [markdown]
# ## **Assumptions & Pitfalls**

# %% [markdown]
# Selection bias
#
# Omitted variable bias
#
# Measurement error
#
# Over-control & collider bias
