# %% [markdown]
# # **Correlation (Tương quan)**

# %% [markdown]
# ## **Pearson Correlation (Tuyến tính)**

# %% [markdown]
# ## **Spearman Correlation (Phi tuyến)**

# %% [markdown]
# ## **Kendall's Tau**

# %% [markdown]
# 🔹 Những “bẫy” thường gặp
#
# Correlation cao nhưng không có quan hệ nhân quả
#
# Outlier làm méo correlation
#
# Non-linear relationship → Pearson thất bại
#
# Simpson’s paradox

# %% [markdown]
# # **Causation (Nhân quả)**

# %% [markdown]
# 🔹 Những câu hỏi cốt lõi
#
# “Nếu can thiệp vào X, Y có thay đổi không?”
#
# “Điều gì xảy ra nếu X không xảy ra?”
#
# 🔹 Các khái niệm nền
#
# Counterfactuals (điều gì sẽ xảy ra nếu…)
#
# Confounder
#
# Mediator
#
# Collider

# %% [markdown]
# # **Causal Graphs & DAGs**

# %% [markdown]
# 🔹 DAG (Directed Acyclic Graph)
#
# Biểu diễn quan hệ nhân quả bằng đồ thị
#
# Giúp quyết định:
#
# Nên kiểm soát biến nào
#
# Không nên kiểm soát biến nào (collider!)
#
# 🔹 Do-calculus (ở mức khái niệm)
#
# Khác nhau giữa:
#
# P(Y | X) – quan sát
#
# P(Y | do(X)) – can thiệp
#
# 👉 Không cần học toán quá nặng, như

# %% [markdown]
# Experimental Causation (Nhân quả qua thí nghiệm)

# %% [markdown]
# Randomized Controlled Trial (RCT)

# %% [markdown]
# 🔹 Randomized Controlled Trial (RCT)
#
# A/B testing
#
# Treatment vs Control
#
# Selection bias
#
# 🔹 Những thứ cần hiểu kỹ
#
# Randomization giúp loại confounder thế nào?
#
# Internal vs External validity

# %% [markdown]
# Observational Causation

# %% [markdown]
# Regression (với tư duy causal, không phải prediction)
#
# Matching (Propensity Score Matching)
#
# Difference-in-Differences
#
# Instrumental Variables
#
# Regression Discontinuity
